# %% [markdown]
# ##1. Write a for loop to print all keys of a dictionary.

# %%
a = {'a':1,'b':2,'c':3}
for i in a:
  print(i)
# Out:
# a
# b
# c

# %% [markdown]
# ##2. Write a for loop to print all values of a dictionary.

# %%
t = {'a':1,'b':2,'c':3}
for i in a.values():
  print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ##3. Write a for loop to print each key and its corresponding value.

# %%
t = {'a':1,'b':2,'c':3}
for i,j in t.items():
  print(i,j)
# Out:
# a 1
# b 2
# c 3

# %% [markdown]
# ##4. Using a while loop, iterate through dictionary keys after converting them into a list.

# %%
veg = {'a':10,'b':32,'c':27,'d':15}
b = list(veg)
i = 0
while i<len(b):
  print(b[i])
  i = i + 1
# Out:
# a
# b
# c
# d

# %% [markdown]
# ##5. Write a program to count how many values in a dictionary are integers using a for loop.

# %%
a = {'a':12,'b':'bcd','c':123,'d':'def'}
b = list(a.values())
print(b)
c=0
for i in b:
  if(type(i))==int:
    c=c+1
  else:
    pass
print(c)
# Out:
# [12, 'bcd', 123, 'def']
# 2

# %% [markdown]
# ##6. Write a for loop to find the sum of all numeric values in a dictionary.

# %%
a = {'a':11,'b':13,'c':14,'d':'p'}
sum = 0
for i in a.values():
  if type(i)==int:
    sum = sum + i
print(sum)
# Out:
# 38

# %% [markdown]
# ##7. Write a while loop to print dictionary items until all keys are printed.

# %%
a = {'a':11,'b':13,'c':14,'d':'p'}
b = list(a)
i = 0
while i<len(b):
  print(i,b[i])
  i=i+1
# Out:
# 0 a
# 1 b
# 2 c
# 3 d

# %% [markdown]
# ##8. Write a program to reverse iterate over dictionary keys using a while loop.

# %%
a = {'a':1,'b':2,'c':3,'d':4}
b = list(a.keys())
n = len(b)-1
while n>=0:
  print(b[n])
  n = n-1
# Out:
# d
# c
# b
# a

# %% [markdown]
# ##9. Write a for loop to print keys whose values are greater than a given number.

# %%
a = {1:12,2:13,3:14,4:15}
for i in a:
  if a[i]>12:
    print(i)
# Out:
# 2
# 3
# 4

# %% [markdown]
# ##10. Write a program to create a new dictionary with only those key value pairs where the value is even.

# %%
a = {'a':10,'b':11,'c':12,'d':13,'e':14}
b = {}
for i in a:
  if a[i]%2==0:
    b.update({i:a[i]})
print(b)
# Out:
# {'a': 10, 'c': 12, 'e': 14}

# %% [markdown]
# ##11. Write a for loop to check if a particular key exists in a dictionary.

# %%
a={'a':10,'b':11,'c':12,'d':13,'e':14}
for i in a:
  if i=='a':
    print(f'a is exist')
# Out:
# a is exist

# %% [markdown]
# ##12. Write a program using while loop to print alternate dictionary keys.

# %%
a = {'a':10,'b':11,'c':12,'d':13,'e':14}
b = list(a)
i = 0
while i<len(b):
  print(b[i])
  i = i + 2
# Out:
# a
# c
# e

# %% [markdown]
# ##13. Write a program to print the length of each value if the value is a string, using a for loop.

# %%
a={'a':'ravali','b':'shiva','c':12,'d':15}

for i in a:
  if type(a[i])==str:
    print(f'{a[i]} the lenght of the string is {len(a[i])}')
# Out:
# ravali the lenght of the string is 6
# shiva the lenght of the string is 5

# %% [markdown]
# ##14. Write a program to print keys that start with a specific letter.

# %%
a = {'shiv':3,'seenu':4,'raju':5}
for i in a:
  if type(i)==str:
    if i.startswith('s'):
      print(i)
# Out:
# shiv
# seenu

# %% [markdown]
# ##15. Write a while loop program to iterate through dictionary items by manually tracking an index.

# %%
a = {'shiv':3,'seenu':4,'raju':5}
b = list(a.items())
i = 0
while i<len(b):
  print(b[i])
  i = i + 1
# Out:
# ('shiv', 3)
# ('seenu', 4)
# ('raju', 5)
